# %%
from kaggle_secrets import UserSecretsClient

# Retrieve the token
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("github_token")

# Define your details
github_user = "sparsh-rastogi-coder"
repo_name = "amazon_ml_winners"

# 1. Clone using the token injected directly into the URL
# !git clone https://{github_user}:{token}@github.com/{github_user}/{repo_name}.git

# 2. Change directory into the cloned repository
# %cd {repo_name}

# 3. Pull the latest changes (optional right after cloning, but good for updates)
# !git pull origin main
# Out:
# Cloning into 'amazon_ml_winners'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 91 (delta 26), reused 78 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (91/91), 42.52 KiB | 2.02 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# /kaggle/working/amazon_ml_winners
# From https://github.com/sparsh-rastogi-coder/amazon_ml_winners
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# %cd {repo_name}

# 3. Pull the latest changes (optional right after cloning, but good for updates)
# !git pull origin main
# Out:
# [Errno 2] No such file or directory: 'amazon_ml_winners'
# /kaggle/working/amazon_ml_winners
# From https://github.com/sparsh-rastogi-coder/amazon_ml_winners
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !pip install sparse_dot_topn
# !pip install unidecode
# !pip install wordninja
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.6/309.6 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.6/541.6 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wordninja: filename=wordninja-2.0.0-py3-none-any.whl size=541553 sha256=b445d7e3d0e51494c8e221fdbaf21bc23254a96776248839903fc79b076c93af
#   Stored in directory: /root/.cache/pip/wheels/6e/31/92/f12667e4dd102e546832a02f41feca39ae916889006517e595
# Successfully built wordninja
# ...

# %%
# !python /kaggle/working/amazon_ml_winners/code/business_entity_resolution/src/evaluate_blocking.py --sample-size 100000 --batch-size 50000
# Out:
# ...
#   BLOCKING EVALUATION
#   Sample size:  100000
#   Top-K (name): 50
#   Top-K (addr): 30
#   Batch size:   50000
# ...
#
# Step 1: Loading S1 sample...
#   US: 59890 entities
#   India: 40110 entities
#   Total: 100000 entities
#
# Step 2: Loading ground truth...
#   Entities with matches: 94452
#   Singletons (no matches): 5548
#   Total true matches: 346089
#
#
# ...
#   Processing country: US (59890 S1 entities)
# ...
#   Loading S1 data...
#   Loading S2 candidates...
#     3016817 S2 entities (57.3s)
#   Loading S3 candidates...
#     3170056 S3 entities (61.3s)
#   Total candidates: 6186873
#   [Name] Fitting TF-IDF on 6186873 candidates...
#   [Name] TF-IDF shape: (6186873, 80000) (took 204.1s)
#   [Name] Finding top-50 candidates...
#   [Name] Done (2871.6s)
#   [Addr] Fitting TF-IDF on 6186873 candidates...
#   [Addr] TF-IDF shape: (6186873, 50000) (took 286.7s)
#   [Addr] Finding top-30 candidates...
#   [Addr] Done (4920.5s)
#   [Comb] Fitting TF-IDF on 6186873 candidates...
# ...
